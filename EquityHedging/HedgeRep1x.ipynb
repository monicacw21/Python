# %%
import empyrial
from empyrial import empyrial, Engine
from empyrial import get_report, Engine

# %%
portfolio = Engine (
                    start_date= "2022-01-01",
                    portfolio= ["SPY", "SDS", "EEM", "EFA", "EUM", "EFZ"],
                    weights= [0.40, 0.20, 0.10, 0.10, 0.10, 0.10],
                    benchmark= ["ACWI"],
                    rebalance= "monthly",
                    
)

empyrial(portfolio)
# Out:
# Start date: 2022-01-01
# End date: 2022-06-19
#                     Backtest
#
# Annual return         -0.22%
# Cumulative return      -0.1%
# Annual volatility     0.31 %
# Winning day ratio     47.27%
# Sharpe ratio           -0.71
# Calmar ratio           -1.45
# Information ratio       0.01
# Stability               0.35
# Max Drawdown         -0.15 %
# Sortino ratio          -0.99
# Skew                    0.15
# Kurtosis                 0.5
# Tail Ratio              0.91
# Common sense ratio      0.81
# Daily value at risk   -0.0 %
# Alpha                   -0.0
# Beta                     0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vy/2xk728253fb8pzdl0w0gbh0c0000gn/T/ipykernel_41265/1123876285.py in <module>
#       8 )
#       9
# ---> 10 empyrial(portfolio)
#
# ...

# %%
get_report(portfolio)
