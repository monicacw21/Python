# %%
import yfinance as yF
import os  
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
stock_data = yF.Ticker("AAPL")

# %%
y_fin = stock_data.financials

# %%
y_fin = y_fin.transpose()

# %%
y_fin = y_fin.rename_axis("date")

# %%
y_fin = y_fin.sort_values(by='date')

# %%
y_fin
# Out:
#            Research Development Effect Of Accounting Charges  \
# date
# 2018-09-29        14236000000.0                         None
# 2019-09-28        16217000000.0                         None
# 2020-09-26        18752000000.0                         None
# 2021-09-25        21914000000.0                         None
#
#            Income Before Tax Minority Interest     Net Income  \
# date
# 2018-09-29     72903000000.0              None  59531000000.0
# 2019-09-28     65737000000.0              None  55256000000.0
# 2020-09-26     67091000000.0              None  57411000000.0
# 2021-09-25    109207000000.0              None  94680000000.0
#
#            Selling General Administrative    Gross Profit            Ebit  \
# date
# 2018-09-29                  16705000000.0  101839000000.0   70898000000.0
# 2019-09-28                  18245000000.0   98392000000.0   63930000000.0
# 2020-09-26                  19916000000.0  104956000000.0   66288000000.0
# ...

# %%
data = y_fin

# %%
yearly_fin_change = data.pct_change(1).mul(100)

# %%
yearly_fin_change = yearly_fin_change.round(2)

# %%
yearly_fin_change
# Out:
#             Research Development Effect Of Accounting Charges  \
# date
# 2018-09-29                   NaN                          NaN
# 2019-09-28                 13.92                          NaN
# 2020-09-26                 15.63                          NaN
# 2021-09-25                 16.86                          NaN
#
#             Income Before Tax Minority Interest  Net Income  \
# date
# 2018-09-29                NaN               NaN         NaN
# 2019-09-28              -9.83               NaN       -7.18
# 2020-09-26               2.06               NaN        3.90
# 2021-09-25              62.77               NaN       64.92
#
#             Selling General Administrative  Gross Profit   Ebit  \
# date
# 2018-09-29                             NaN           NaN    NaN
# 2019-09-28                            9.22         -3.38  -9.83
# 2020-09-26                            9.16          6.67   3.69
# 2021-09-25                           10.33         45.62  64.36
#
# ...

# %%
yearly_fin_change = yearly_fin_change.iloc[1: , :]

# %%
yearly_fin_change = yearly_fin_change.dropna(axis='columns')

# %%
yearly_fin_change
# Out:
#             Research Development  Income Before Tax  Net Income  \
# date
# 2019-09-28                 13.92              -9.83       -7.18
# 2020-09-26                 15.63               2.06        3.90
# 2021-09-25                 16.86              62.77       64.92
#
#             Selling General Administrative  Gross Profit   Ebit  \
# date
# 2019-09-28                            9.22         -3.38  -9.83
# 2020-09-26                            9.16          6.67   3.69
# 2021-09-25                           10.33         45.62  64.36
#
#             Operating Income  Interest Expense  Income Tax Expense  \
# date
# 2019-09-28             -9.83             10.37              -21.62
# 2020-09-26              3.69            -19.66               -7.64
# 2021-09-25             64.36             -7.94               50.07
#
#             Total Revenue  Total Operating Expenses  Cost Of Revenue  \
# date
# 2019-09-28          -2.04                      0.79            -1.21
# ...

# %%
plt.figure(figsize = (30,12))
sns.heatmap(yearly_fin_change, annot = True, cmap="YlGnBu")


plt.title("Financial Change YoY %", size=20)
plt.xlabel("Feature")
plt.ylabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
