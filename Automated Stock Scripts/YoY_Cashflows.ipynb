# %%
import yfinance as yF
import os  
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
stock_data = yF.Ticker("AAPL")

# %%
y_cas = stock_data.cashflow

# %%
y_cas = y_cas.transpose()

# %%
y_cas = y_cas.rename_axis("date")

# %%
y_cas = y_cas.sort_values(by='date')

# %%
y_cas
# Out:
#              Investments  Change To Liabilities  \
# date
# 2018-09-29  3.084500e+10           9.172000e+09
# 2019-09-28  5.809300e+10          -2.548000e+09
# 2020-09-26  5.335000e+09          -1.981000e+09
# 2021-09-25 -2.819000e+09           1.400200e+10
#
#             Total Cashflows From Investing Activities  Net Borrowings  \
# date
# 2018-09-29                               1.606600e+10    4.320000e+08
# 2019-09-28                               4.589600e+10   -7.819000e+09
# 2020-09-26                              -4.289000e+09    2.499000e+09
# 2021-09-25                              -1.454500e+10    1.266500e+10
#
#             Total Cash From Financing Activities  \
# date
# 2018-09-29                         -8.787600e+10
# 2019-09-28                         -9.097600e+10
# 2020-09-26                         -8.682000e+10
# 2021-09-25                         -9.335300e+10
#
#             Change To Operating Activities  Issuance Of Stock    Net Income  \
# date
# ...

# %%
data = y_cas

# %%
yearly_cas_change = data.pct_change(1).mul(100)

# %%
yearly_cas_change = yearly_cas_change.round(2)

# %%
yearly_cas_change
# Out:
#             Investments  Change To Liabilities  \
# date
# 2018-09-29          NaN                    NaN
# 2019-09-28        88.34                -127.78
# 2020-09-26       -90.82                 -22.25
# 2021-09-25      -152.84                -806.81
#
#             Total Cashflows From Investing Activities  Net Borrowings  \
# date
# 2018-09-29                                        NaN             NaN
# 2019-09-28                                     185.67        -1909.95
# 2020-09-26                                    -109.35         -131.96
# 2021-09-25                                     239.12          406.80
#
#             Total Cash From Financing Activities  \
# date
# 2018-09-29                                   NaN
# 2019-09-28                                  3.53
# 2020-09-26                                 -4.57
# 2021-09-25                                  7.52
#
#             Change To Operating Activities  Issuance Of Stock  Net Income  \
# date
# ...

# %%
yearly_cas_change = yearly_cas_change.iloc[1: , :]

# %%
yearly_cas_change = yearly_cas_change.dropna(axis='columns')

# %%
yearly_cas_change
# Out:
#             Investments  Change To Liabilities  \
# date
# 2019-09-28        88.34                -127.78
# 2020-09-26       -90.82                 -22.25
# 2021-09-25      -152.84                -806.81
#
#             Total Cashflows From Investing Activities  Net Borrowings  \
# date
# 2019-09-28                                     185.67        -1909.95
# 2020-09-26                                    -109.35         -131.96
# 2021-09-25                                     239.12          406.80
#
#             Total Cash From Financing Activities  \
# date
# 2019-09-28                                  3.53
# 2020-09-26                                 -4.57
# 2021-09-25                                  7.52
#
#             Change To Operating Activities  Issuance Of Stock  Net Income  \
# date
# 2019-09-28                         -102.99              16.74       -7.18
# 2020-09-26                         -198.33              12.68        3.90
# ...

# %%
plt.figure(figsize = (30,12))
sns.heatmap(yearly_cas_change, annot = True, cmap="YlGnBu")


plt.title("Cash Flow Change YoY %", size=20)
plt.xlabel("Feature")
plt.ylabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
